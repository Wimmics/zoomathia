# %%
#%endpoint http://erebe-vm22.i3s.unice.fr/repositories/zoomathia
%endpoint http://54.36.123.165:8890/sparql/

# %%
%show 20
# Request whatever format is appropriate for the query type
%format default

# Activate table output
%display table
# Out:
# Result maximum size: 20
# Request format: DEFAULT
# Display: table

# %%
%prefix rdf:     <http://www.w3.org/1999/02/22-rdf-syntax-ns#> 
%prefix rdfs:    <http://www.w3.org/2000/01/rdf-schema#> 
%prefix oa:     <http://www.w3.org/ns/oa#>
%prefix skos: <http://www.w3.org/2004/02/skos/core#>
%prefix schema:  <http://schema.org/>
%prefix paragraph: <http://www.zoomathia.com/>
# Out:
# Prefix set: rdf: = <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# Prefix set: rdfs: = <http://www.w3.org/2000/01/rdf-schema#>
# Prefix set: oa: = <http://www.w3.org/ns/oa#>
# Prefix set: skos: = <http://www.w3.org/2004/02/skos/core#>
# Prefix set: schema: = <http://schema.org/>
# Prefix set: paragraph: = <http://www.zoomathia.com/>

# %% [markdown]
# # CQ1

# %% [markdown]
# The first SPARQL query allows scientists to identify which animals are able to construct a favorable habitat. The resuslt of this qyery indicates for example that paragraph 10 of the chapter 10 mentions that AQUILA (EAGLE) build a nest.

# %%
SELECT DISTINCT ?paragraph ?name_animal ?mention_animal ?name_construction ?mention_construction WHERE {
  ?annotation1 a oa:Annotation;
              oa:hasBody ?animal;
              oa:hasTarget ?target1.
  ?target1 oa:hasSource ?paragraph;
     oa:hasSelector ?selector.
    
  ?selector oa:exact ?mention_animal.

  ?animal a skos:Concept;
       skos:prefLabel ?name_animal.
    
  ?animal_collection a skos:Collection;
       skos:prefLabel "Ancient class"@en;
       skos:member ?animal.

  ?annotation2 oa:hasBody ?construction;
        oa:hasTarget ?target2.
  ?target2 oa:hasSource ?paragraph;
      oa:hasSelector ?selector2.
  ?selector2 oa:exact ?mention_construction.

  ?construction skos:prefLabel ?name_construction;
     	            skos:broader+ ?construction_generique.
  ?construction_generique skos:prefLabel "house building"@en.

  FILTER (lang(?name_animal) = "en").
  FILTER (lang(?name_construction) = "en")
}
ORDER BY ?paragraph
# Out:
# <div class="krn-spql"><table><tr class=hdr><th>paragraph</th>
# <th>name_animal</th>
# <th>mention_animal</th>
# <th>name_construction</th>
# <th>mention_construction</th></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/10" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/10</a></td>
# <td class=val>AQUILA</td>
# <td class=val>aquilarum</td>
# <td class=val>nest</td>
# <td class=val>e nido</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/100" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/100</a></td>
# <td class=val>WILD BEAST</td>
# <td class=val>ut contra feram</td>
# <td class=val>nest</td>
# <td class=val>spina et frutice sic muniunt receptaculum, ut contra feram abunde vallentur.</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/100" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/100</a></td>
# <td class=val>quail</td>
# <td class=val>coturnices</td>
# <td class=val>nest</td>
# <td class=val>spina et frutice sic muniunt receptaculum, ut contra feram abunde vallentur.</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/100" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/100</a></td>
# <td class=val>hen</td>
# <td class=val>gallinaceos</td>
# <td class=val>nest</td>
# <td class=val>spina et frutice sic muniunt receptaculum, ut contra feram abunde vallentur.</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/100" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/100</a></td>
# <td class=val>rooster</td>
# <td class=val>gallinaceos</td>
# <td class=val>nest</td>
# <td class=val>spina et frutice sic muniunt receptaculum, ut contra feram abunde vallentur.</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/104" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/104</a></td>
# <td class=val>partridge</td>
# <td class=val>Perdices spina et frutice sic muniunt receptaculum, ut contra feram abunde vallentur. ovis stragulum molle pulvere contumulant nec in quo loco peperere incubant: ne cui frequentior conversatio suspecta sit, transferunt alio. illae quidem et maritos suos fallunt, quoniam intemperantia libidinis frangunt earum ova, ne incubando detineantur. tunc inter se dimicant mares desiderio feminarum; victum aiunt venerem pati. [[101]] id quidem et coturnices Trogus et gallinaceos aliquando, perdices vero a domitis feros et novos aut victos iniri promiscue. capiuntur quoque pugnacitate eiusdem libidinis, contra aucupis in&lt;l&gt;icem exeunte in proelium duce totius gregis. capto eo procedit alter ac subinde singuli. rursus circa conceptum feminae capiuntur contra aucupum feminam exeuntes, ut rixando abigant e&lt;a&gt;m. [[102]] nec in alio animali par opus libidinis. si contra mares steterint, feminae aura ab &lt;i&gt;is flante praegnantes fiunt, hiantes autem exerta lingua per id tempus aestuant. concipiunt et supervolantium adflatu, saepe voce tantum audita masculi, adeoque vincit libido etiam fetus caritatem, ut illa furtim et in occulto incubans, cum sensit feminam aucupis accedentem ad marem, recanat revocetque et ultro praebeat se libidini. rabie quidem tanta feruntur, ut in capite aucupantium saepe caecae m&lt;o&gt;tu sedeant. [[103]] si ad nidum is coepit accedere, procurrit ad pedes eius feta, praegravem aut delumbem sese simulans, subitoque in procursu aut brevi aliquo volatu cadit, ut fracta ala aut pedibus, at procurrit iterum iamiam pre&lt;hen&gt;surum effugiens spemque frustrans, donec in diversum abducat a nidis. eadem in pavore, libera ac materna vacan&lt;s&gt; cura, in sulco resupina glaeba se terrae pedibus adprehensa operit. perdicum vita et ad sedecim  annos durare existimatur.  [[104]] Ab &lt;i&gt;is</td>
# <td class=val>nest</td>
# <td class=val>nidum</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/104" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/104</a></td>
# <td class=val>bee eater</td>
# <td class=val>merops vocatur genitores suos reconditos pascens, pallido intus colore pinnarum, superne cyaneo, prior&lt;e parte&gt; subrutilo. nidificat in specu sex pedum defossa altitudine.</td>
# <td class=val>nest</td>
# <td class=val>nidum</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/114" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/114</a></td>
# <td class=val>swallow1</td>
# <td class=val>hirundinum specie</td>
# <td class=val>nest</td>
# <td class=val>in nido</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/114" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/114</a></td>
# <td class=val>swallow1</td>
# <td class=val>hirundinum specie</td>
# <td class=val>nest</td>
# <td class=val>nidificant in scopulis</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/126" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/126</a></td>
# <td class=val>cataracta</td>
# <td class=val>Iuba cataractas vocat, et eis esse dentes oculosque igneo colore cetero candidis tradens.</td>
# <td class=val>nest</td>
# <td class=val>scrobes excavare rostro, inde crate consternere et operire terra quae ante fuerit egesta; in his fetificare. fores binas omnium scrobibus: orientem spectare quibus exeant in pascua, occasum quibus redeant.</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/13" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/13</a></td>
# <td class=val>WILD BEAST</td>
# <td class=val>ne omnium ferarum fetus raperentur</td>
# <td class=val>nest</td>
# <td class=val>Tribus primis et quinto aquilarum generi inaedificatur nido lapis aetites, quem aliqui dixere gagiten, ad multa remedia utilis, nihil igne deperdens. _est autem lapis iste praegnans intus alio, cum quatias, velut in utero sonante. _sed vis illa medica non nisi nido dereptis. [[13]] nidificant in petris et arboribus,</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/13" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/13</a></td>
# <td class=val>black eagle</td>
# <td class=val>Tribus primis et quinto aquilarum generi inaedificatur nido lapis aetites</td>
# <td class=val>nest</td>
# <td class=val>Tribus primis et quinto aquilarum generi inaedificatur nido lapis aetites, quem aliqui dixere gagiten, ad multa remedia utilis, nihil igne deperdens. _est autem lapis iste praegnans intus alio, cum quatias, velut in utero sonante. _sed vis illa medica non nisi nido dereptis. [[13]] nidificant in petris et arboribus,</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/13" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/13</a></td>
# <td class=val>pygargus2</td>
# <td class=val>Tribus primis et quinto aquilarum generi inaedificatur nido lapis aetites</td>
# <td class=val>nest</td>
# <td class=val>Tribus primis et quinto aquilarum generi inaedificatur nido lapis aetites, quem aliqui dixere gagiten, ad multa remedia utilis, nihil igne deperdens. _est autem lapis iste praegnans intus alio, cum quatias, velut in utero sonante. _sed vis illa medica non nisi nido dereptis. [[13]] nidificant in petris et arboribus,</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/13" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/13</a></td>
# <td class=val>morphnos</td>
# <td class=val>Tribus primis et quinto aquilarum generi inaedificatur nido lapis aetites</td>
# <td class=val>nest</td>
# <td class=val>Tribus primis et quinto aquilarum generi inaedificatur nido lapis aetites, quem aliqui dixere gagiten, ad multa remedia utilis, nihil igne deperdens. _est autem lapis iste praegnans intus alio, cum quatias, velut in utero sonante. _sed vi

# %% [markdown]
# # CQ2

# %% [markdown]
# The SPARQL query allows to identify the textual passages that allow for the identification of possible interactions between humans and animals such as predation friendship and animosity.

# %%
SELECT DISTINCT ?paragraph ?name_animal ?name_relation ?name_anthro WHERE {
    
  ?annotation1 a oa:Annotation;
               oa:hasBody ?animal;
               oa:hasTarget ?target1.
    
  ?target1 oa:hasSource ?paragraph;
           oa:hasSelector ?selector.
    
 ?selector oa:exact ?mention_animal.

  ?annotation2 oa:hasBody ?relation;
               oa:hasTarget ?target2.
    
  ?target2 oa:hasSource ?paragraph;
           oa:hasSelector ?selector2.
    
  ?selector2 oa:exact ?mention_relation.

   ?annotation3 oa:hasBody ?anthro;
                oa:hasTarget ?target3.
    
  ?target3 oa:hasSource ?paragraph;
           oa:hasSelector ?selector3.
    
  ?selector3 oa:exact ?mention_anthro.

  ?animal a skos:Concept;
           skos:prefLabel ?name_animal.
    
  ?animal_collection a skos:Collection;
                       skos:prefLabel "Ancient class"@en;
                       skos:member ?animal.

  ?relation skos:prefLabel ?name_relation;
            skos:broader+ ?relation_generique.
    
  ?relation_generique skos:prefLabel  "special relationship"@en.

 ?anthro skos:prefLabel ?name_anthro.
    
 ?anthro_collection skos:prefLabel ?anthro_collection_name;
                    skos:member ?anthro.

  FILTER (lang(?name_animal) = "en").
  FILTER (lang(?name_relation) = "en").
  FILTER (lang(?name_anthro) = "en").
  FILTER (?anthro_collection_name in ("Place"@en, "Anthroponym"@en))
}
ORDER BY ?paragraph
# Out:
# <div class="krn-spql"><table><tr class=hdr><th>paragraph</th>
# <th>name_animal</th>
# <th>name_relation</th>
# <th>name_anthro</th></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/138" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/138</a></td>
# <td class=val>BIRD</td>
# <td class=val>predation</td>
# <td class=val>historical character</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/138" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/138</a></td>
# <td class=val>BIRD</td>
# <td class=val>predation</td>
# <td class=val>Homer</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/138" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/138</a></td>
# <td class=val>BIRD</td>
# <td class=val>predation</td>
# <td class=val>Democritus</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/202" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/202</a></td>
# <td class=val>FLYING ANIMAL</td>
# <td class=val>predation</td>
# <td class=val>Africa</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/202" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/202</a></td>
# <td class=val>BIRD</td>
# <td class=val>predation</td>
# <td class=val>Africa</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/202" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/202</a></td>
# <td class=val>leopard</td>
# <td class=val>predation</td>
# <td class=val>Africa</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/202" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/202</a></td>
# <td class=val>scorpion</td>
# <td class=val>predation</td>
# <td class=val>Africa</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/207" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/207</a></td>
# <td class=val>parrot</td>
# <td class=val>enmity</td>
# <td class=val>Arcadian city</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/207" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/207</a></td>
# <td class=val>fox</td>
# <td class=val>enmity</td>
# <td class=val>Arcadian city</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/207" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/207</a></td>
# <td class=val>snake</td>
# <td class=val>enmity</td>
# <td class=val>Arcadian city</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/207" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/207</a></td>
# <td class=val>turtledove</td>
# <td class=val>enmity</td>
# <td class=val>Arcadian city</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/207" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/207</a></td>
# <td class=val>heron</td>
# <td class=val>enmity</td>
# <td class=val>Arcadian city</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/207" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/207</a></td>
# <td class=val>blackbird</td>
# <td class=val>enmity</td>
# <td class=val>Arcadian city</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/207" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/207</a></td>
# <td class=val>bearded vulture</td>
# <td class=val>enmity</td>
# <td class=val>Arcadian city</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/207" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/207</a></td>
# <td class=val>kite</td>
# <td class=val>enmity</td>
# <td class=val>Arcadian city</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/207" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/207</a></td>
# <td class=val>triorchis</td>
# <td class=val>enmity</td>
# <td class=val>Arcadian city</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/207" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/207</a></td>
# <td class=val>crow</td>
# <td class=val>enmity</td>
# <td class=val>Arcadian city</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/208" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/208</a></td>
# <td class=val>asp</td>
# <td class=val>enmity</td>
# <td class=val>Phylarchus</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/22" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/22</a></td>
# <td class=val>FLYING ANIMAL</td>
# <td class=val>predation</td>
# <td class=val>Ocean</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/22" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/22</a></td>
# <td class=val>FLYING ANIMAL</td>
# <td class=val>predation</td>
# <td class=val>Africa</td></tr></table><div class="tinfo">Total: 197, Shown: 20</div></div>

# %% [markdown]
# # QC3

# %% [markdown]
# This SPARQL query allows researchers to identify the animals that have been used for gastronomic use

# %%
SELECT DISTINCT ?paragraph ?name_animal ?mention_animal ?name_conso ?mention_conso WHERE {
  ?annotation1 a oa:Annotation;
              oa:hasBody ?animal;
              oa:hasTarget ?target1.
  ?target1 oa:hasSource ?paragraph;
     oa:hasSelector ?selector.
    
  ?selector oa:exact ?mention_animal.

  ?animal a skos:Concept;
       skos:prefLabel ?name_animal;
       skos:broader+ ?animal_generique.
    
  ?animal_generique a skos:Concept;
       skos:prefLabel ?name_animal_generique.

  ?annotation2 oa:hasBody ?conso;
        oa:hasTarget ?target2.
  ?target2 oa:hasSource ?paragraph;
      oa:hasSelector ?selector2.
  ?selector2 oa:exact ?mention_conso.

  ?conso skos:prefLabel ?name_conso;
         skos:broader+ ?conso_generique.
  ?conso_generique skos:prefLabel "animal in human nourishing"@en.

  FILTER (str(?name_animal_generique) in ("BIRD","BIRD WITH CLAW","BIRD WITH TOES","WATERBIRD","NIGHT BIRD","MIGRATORY BIRD", "PALMIPED BIRD")).
  FILTER (lang(?name_animal) = "en").
  FILTER (lang(?name_conso) = "en")
}
ORDER BY ?paragraph
# Out:
# <div class="krn-spql"><table><tr class=hdr><th>paragraph</th>
# <th>name_animal</th>
# <th>mention_animal</th>
# <th>name_conso</th>
# <th>mention_conso</th></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/133" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/133</a></td>
# <td class=val>pyrrhocorax</td>
# <td class=val>pyrrhocorax, luteo rostro niger</td>
# <td class=val>cooking</td>
# <td class=val>praecipua sapore</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/133" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/133</a></td>
# <td class=val>phalacrocorax</td>
# <td class=val>&lt;circa&gt; Alpes etiam, ubi et phalacrocoraces, avis Baliarium insularum peculiaris</td>
# <td class=val>cooking</td>
# <td class=val>praecipua sapore</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/133" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/133</a></td>
# <td class=val>pyrrhocorax</td>
# <td class=val>pyrrhocorax, luteo rostro niger</td>
# <td class=val>cooking</td>
# <td class=val>linguam praecipui saporis esse Apicius docuit</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/133" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/133</a></td>
# <td class=val>phalacrocorax</td>
# <td class=val>&lt;circa&gt; Alpes etiam, ubi et phalacrocoraces, avis Baliarium insularum peculiaris</td>
# <td class=val>cooking</td>
# <td class=val>linguam praecipui saporis esse Apicius docuit</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/133" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/133</a></td>
# <td class=val>attagen</td>
# <td class=val>attagen maxime Ionius celeber et vocalis alias, captus vero obmutescens, quondam existimatus inter raras aves, iam et in Gallia Hispaniaque. capitur &lt;circa&gt; Alpes etiam,</td>
# <td class=val>cooking</td>
# <td class=val>praecipua sapore</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/133" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/133</a></td>
# <td class=val>flamingo</td>
# <td class=val>Phoenicopteri linguam praecipui saporis esse Apicius docuit, nepotum omnium altissimus gurges.</td>
# <td class=val>cooking</td>
# <td class=val>linguam praecipui saporis esse Apicius docuit</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/133" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/133</a></td>
# <td class=val>attagen</td>
# <td class=val>attagen maxime Ionius celeber et vocalis alias, captus vero obmutescens, quondam existimatus inter raras aves, iam et in Gallia Hispaniaque. capitur &lt;circa&gt; Alpes etiam,</td>
# <td class=val>cooking</td>
# <td class=val>linguam praecipui saporis esse Apicius docuit</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/133" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/133</a></td>
# <td class=val>flamingo</td>
# <td class=val>Phoenicopteri linguam praecipui saporis esse Apicius docuit, nepotum omnium altissimus gurges.</td>
# <td class=val>cooking</td>
# <td class=val>praecipua sapore</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/134" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/134</a></td>
# <td class=val>ibis</td>
# <td class=val>visam in Alpibus ab se peculiarem Aegypti et ibim Egnatius Calvinus praefectus earum prodidit</td>
# <td class=val>cooking</td>
# <td class=val>croceo unctu cibis gratissima</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/134" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/134</a></td>
# <td class=val>quail</td>
# <td class=val>coturnicibus magnitudine tantum differens</td>
# <td class=val>cooking</td>
# <td class=val>non extra terram eam vesci facile, quando nec vita mansuescit et corpus ocissime marcescit</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/134" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/134</a></td>
# <td class=val>ibis</td>
# <td class=val>visam in Alpibus ab se peculiarem Aegypti et ibim Egnatius Calvinus praefectus earum prodidit</td>
# <td class=val>cooking</td>
# <td class=val>non extra terram eam vesci facile, quando nec vita mansuescit et corpus ocissime marcescit</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/134" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/134</a></td>
# <td class=val>quail</td>
# <td class=val>coturnicibus magnitudine tantum differens</td>
# <td class=val>cooking</td>
# <td class=val>croceo unctu cibis gratissima</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/134" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/134</a></td>
# <td class=val>lagopus1</td>
# <td class=val>praecipua sapore lagopus. pedes leporino villo nomen hoc dedere cetero candidae, columbarum magnitudine.  [[134]] non extra terram eam vesci facile, quando nec vita mansuescit et corpus ocissime marcescit.</td>
# <td class=val>cooking</td>
# <td class=val>croceo unctu cibis gratissima</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/134" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/134</a></td>
# <td class=val>lagopus1</td>
# <td class=val>praecipua sapore lagopus. pedes leporino villo nomen hoc dedere cetero candidae, columbarum magnitudine.  [[134]] non extra terram eam vesci facile, quando nec vita mansuescit et corpus ocissime marcescit.</td>
# <td class=val>cooking</td>
# <td class=val>non extra terram eam vesci facile, quando nec vita mansuescit et corpus ocissime marcescit</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/136" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/136</a></td>
# <td class=val>pegasus2</td>
# <td class=val>Pegasos equino capite volucres</td>
# <td class=val>cooking</td>
# <td class=val>Venerunt in Italiam Bedriacensibus bellis civilibus trans Padum et novae aves _ita enim adhuc vocantur_, turdorum specie, paulum infra columbas magnitudine, sapore gratae. Baliares insulae nobiliorem etiam supra dicto porphyrionem mittunt. ibi et buteo accipitrum generis in honore mensarum est, item vibiones; sic vocant minorem gruem.</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/136" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/136</a></td>
# <td class=val>tragopan</td>
# <td class=val>equidem et tragopana, de qua plures adfirmant, maiorem aquila, cornua in temporibus curvata habentem, ferruginei coloris, tantum capite phoeniceo.</td>
# <td class=val>cooking</td>
# <td class=val>Venerunt in Italiam Bedriacensibus bellis civilibus trans Padum et novae aves _ita enim adhuc vocantur_, turdorum specie, paulum infra columbas magnitudine, sapore gratae. Baliares insulae nobiliorem etiam supra dicto porphyrionem mittunt. ibi et buteo accipitrum generis in honore mensarum est, item vibiones; sic vocant minorem gruem.</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/136" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/136</a></td>
# <td class=val>siren</td>
# <td class=val>Sirenes impetraverint fidem, adfirmet licet Dinon, Clitarchi celebrati auctoris pater, in India esse mulcerique earum cantu quos gravatos somno lacerent.</td>
# <td class=val>cooking</td>
# <td class=val>Venerunt in Italiam Bedriacensibus bellis civilibus trans Padum et novae aves _ita enim adhuc vocantur_, turdorum specie, paulum infra columbas magnitudine, sapore gratae. Baliares insulae nobiliorem etiam supra dicto porphyrionem mittunt. ibi et buteo accipitrum generis in honore mensarum est, item vibiones;

# %% [markdown]
# # CQ4

# %% [markdown]
# This SPARQL query allows researchers to identify the animals that have been used for medical purposes and more precisely the part of the body of the animal.

# %%
SELECT DISTINCT ?paragraph ?name_animal ?mention1 ?mention2 WHERE {
  ?annotation1 a oa:Annotation;
              oa:hasBody ?animal;
              oa:hasTarget ?target1.
  ?target1 oa:hasSource ?paragraph;
     oa:hasSelector ?selector1.

?annotation2 a oa:Annotation;
              oa:hasBody ?use;
              oa:hasTarget ?target2.
  ?target2 oa:hasSource ?paragraph;
     oa:hasSelector ?selector2.
    
  ?selector1 oa:exact ?mention1.
  ?selector2 oa:exact ?mention2.

  ?animal a skos:Concept;
       skos:prefLabel ?name_animal.
    
  ?animal_collection a skos:Collection;
       skos:prefLabel "Ancient class"@en;
       skos:member ?animal.

  ?use skos:prefLabel ?name_use;
       skos:broader+ ?use_generique.
  ?use_generique skos:prefLabel "medical use of animal"@en.
  
  FILTER (lang(?name_animal) = "en").
  FILTER (lang(?name_use) = "en")
}
ORDER BY ?paragraph
# Out:
# <div class="krn-spql"><table><tr class=hdr><th>paragraph</th>
# <th>name_animal</th>
# <th>mention1</th>
# <th>mention2</th></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/12" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/12</a></td>
# <td class=val>AQUILA</td>
# <td class=val>aquilarum</td>
# <td class=val>ad multa remedia utilis, nihil igne deperdens. _est autem lapis iste praegnans intus alio, cum quatias, velut in utero sonante. _sed vis illa medica non nisi nido dereptis</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/55" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/55</a></td>
# <td class=val>rooster</td>
# <td class=val>Proxime gloriam sentiunt et hi nostri vigiles nocturni, quos excitandis in opera mortalibus rumpendoque somno natura genuit. norunt sidera et ternas distinguunt horas interdiu cantu. cum sole eunt cubitum quartaque castrensi vigilia ad curas laboremque revocant nec solis ortum incautis patiuntur obrepere diemque venientem nuntiant cantu, ipsum vero cantum plausu laterum.  [[47]] imperitant suo generi et regnum in quacumque sunt domo exercent. dimicatione paritur hoc inter ipsos velut ideo tela agnata cruribus suis intellegentium, nec finis saepe commorientibus. quod si palma contigit, statim in victoria canunt seque ipsi principes testantur; victus occultatur silens aegreque servitium patitur. et plebs tamen aeque superba graditur ardua cervice, cristis celsa, caelumque sola volucrum aspicit crebra, in sublime caudam quoque falcatam erigens. itaque  [[48]] terrori sunt etiam leonibus ferarum generosissimis. iam ex his quidam ad bella tantum et proelia adsidua nascuntur_ quibus etiam patrias nobilitarunt, Rhodum aut Tanagram; secundus est honos habitus Melicis et Chalcidicis_, ut plane dignae aliti tantum honoris perhibeat Romana purpura. [[49]] horum sunt tripudia solistima, hi magistratus nostros cotidie regunt domusque ipsis suas claudunt aut reserant. hi fasces Romanos inpellunt aut retinent, iubent acies aut prohibent, victoriarum omnium toto orbe partarum auspices. hi maxime terrarum imperio imperant, ex&lt;t&gt;is etiam fibrisque haut aliter quam opimae victimae diis grati. habent ostenta et praeposteri eorum vespertinique cantus: namque totis noctibus canendo Boeotiis nobilem illam adversus Lacedaemonios praesagivere victoriam, ita coniecta interpretatione, quoniam victa ales illa non caneret.  [[50]] Desinunt canere castrati, quod duobus fit modis, lumbis adustis candente ferro aut imis cruribus, mox ulcere oblito figlina creta; facilius ita pinguescunt. Pergami omnibus annis spectaculum gallorum publice editur ceugladiatorum. invenitur in annalibus in agro Ariminensi M. Lepido Q. Catulo cos. in villa Galerii locutum gallinaceum, semel, quod equidem sciam.</td>
# <td class=val>Aliud repperit Syriae pars quae Commagene vocatur, adipem eorum in vase aereo cum cinnamo nive multa obrutum ac rigore gelid&lt;o&gt; maceratum ad usum praeclari medicaminis, quod ab gente dicitur Commagenum</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-11-annoteIPL/11/118" target="_other">http://www.zoomathia.com/PLINE-11-annoteIPL/11/118</a></td>
# <td class=val>snail</td>
# <td class=val>tunicas suas trahentium quo cocleae modo</td>
# <td class=val>alae medentur</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-11-annoteIPL/11/118" target="_other">http://www.zoomathia.com/PLINE-11-annoteIPL/11/118</a></td>
# <td class=val>gnat</td>
# <td class=val>rursus alia genera culicum acescens natura gignit,</td>
# <td class=val>alae medentur</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-11-annoteIPL/11/118" target="_other">http://www.zoomathia.com/PLINE-11-annoteIPL/11/118</a></td>
# <td class=val>VERMIS</td>
# <td class=val>vermiculi rutili_nam et ipsa nix vetustate rufescit_ hirti pilis, in Media quidem candidi, grandiores torpentesque</td>
# <td class=val>alae medentur</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-11-annoteIPL/11/118" target="_other">http://www.zoomathia.com/PLINE-11-annoteIPL/11/118</a></td>
# <td class=val>VERMIS</td>
# <td class=val>vermiculi</td>
# <td class=val>alae medentur</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-11-annoteIPL/11/118" target="_other">http://www.zoomathia.com/PLINE-11-annoteIPL/11/118</a></td>
# <td class=val>caterpillar with robe</td>
# <td class=val>est earum genus tunicas suas trahentium quo cocleae modo; sed harum pedes cernuntur. spoliatae &lt;ex&gt;-  [[118]] spirant. si adcrevere, faciunt chrysallidem.</td>
# <td class=val>alae medentur</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-11-annoteIPL/11/118" target="_other">http://www.zoomathia.com/PLINE-11-annoteIPL/11/118</a></td>
# <td class=val>fig gnat</td>
# <td class=val>ficarios culices caprificus generat</td>
# <td class=val>alae medentur</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-11-annoteIPL/11/118" target="_other">http://www.zoomathia.com/PLINE-11-annoteIPL/11/118</a></td>
# <td class=val>cantharides</td>
# <td class=val>cantharidas vermiculi ficorum et piri et peuces et cynacanthae et rosae. venenum hoc remedia secum habet: alae medentur, quibus demptis letale est.</td>
# <td class=val>alae medentur</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-11-annoteIPL/11/118" target="_other">http://www.zoomathia.com/PLINE-11-annoteIPL/11/118</a></td>
# <td class=val>red worm born from snow</td>
# <td class=val>in nive inveniantur vetustiore vermiculi rutili_nam et ipsa nix vetustate rufescit_ hirti pilis,</td>
# <td class=val>alae medentur</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-11-annoteIPL/11/118" target="_other">http://www.zoomathia.com/PLINE-11-annoteIPL/11/118</a></td>
# <td class=val>white worm born from snow</td>
# <td class=val>in Media quidem candidi, grandiores torpentesque</td>
# <td class=val>alae medentur</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-11-annoteIPL/11/67" target="_other">http://www.zoomathia.com/PLINE-11-annoteIPL/11/67</a></td>
# <td class=val>ENTOMON</td>
# <td class=val>omnia insecta</td>
# <td class=val>remedia dicemus suis locis; nunc enim sermo de natura est.</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-8-annoteIPL/8/109" target="_other">http://www.zoomathia.com/PLINE-8-annoteIPL/8/109</a></td>
# <td class=val>AQUATIC</td>
# <td class=val>Vtrumque aquaticum</td>
# <td class=val>castoreum id vocant medici</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-8-annoteIPL/8/109" target="_other">http://www.zoomathia.com/PLINE-8-annoteIPL/8/109</a></td>
# <td class=val>wild ass</td>
# <td class=val>in Africa, quae et asinorum silvestrium multitudinem fundit. mares in eo genere singuli feminarum gregibus imperitant; timent libidinis aemulos et ideo gravidas custodiunt morsu que natos mares castrant. contra gravidae latebras petunt et parere furto cupiunt gaudent que copia libidinis.</td>
# <td class=val>castoreum id vocant medici</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-8-annoteIPL/8/109" target="_other">http://www.zoomathia.com/PLINE-8-annoteIPL/8/109</a></td>
# <td class=val>FISH</td>
# <td class=val>Cauda piscium his</td>
# <td class=val>castoreum id vocant medici</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-8-annoteIPL/8/109" target="_other">http://www.zoomathia.com/PLINE-8-annoteIPL/8/109</a></td>
# <td class=val>otter</td>
# <td class=val>cetera species lutrae. Vtrumque aquaticum, utrique mollior pluma pilus</td>
# <td class=val>castoreum id vocant medici</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-8-annoteIPL/8/111" target="_other">http://www.zoomathia.com/PLINE-8-annoteIPL/8/111</a></td>
# <td class=val>frog</td>
# <td class=val>Rana

# %% [markdown]
# # CQ5

# %% [markdown]
# This SPARQL query allow to identify in the text the communication mode (language) between annimals.

# %%
SELECT DISTINCT ?paragraph ?name_animal ?mention_animal ?mention_social WHERE {
    
  ?annotation1 a oa:Annotation;
              oa:hasBody ?animal;
              oa:hasTarget ?target1.
  ?target1 oa:hasSource ?paragraph;
     oa:hasSelector ?selector.
    
  ?selector oa:exact ?mention_animal.

  ?animal a skos:Concept;
       skos:prefLabel ?name_animal.
    
  ?animal_collection a skos:Collection;
       skos:prefLabel "Ancient class"@en;
       skos:member ?animal.

 ?annotation2 oa:hasBody ?social;
        oa:hasTarget ?target2.
  ?target2 oa:hasSource ?paragraph;
      oa:hasSelector ?selector2.
  ?selector2 oa:exact ?mention_social.
    
  ?social skos:prefLabel "speech"@en.
      

    
  FILTER (lang(?name_animal) = "en").
}
ORDER BY ?paragraph
# Out:
# <div class="krn-spql"><table><tr class=hdr><th>paragraph</th>
# <th>name_animal</th>
# <th>mention_animal</th>
# <th>mention_social</th></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/117" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/117</a></td>
# <td class=val>parrot</td>
# <td class=val>super omnia humanas voces reddunt, psittaci quidem etiam sermocinantes. India hanc avem mittit, siptacen vocat, viridem toto corpore, torque tantum miniato in cervice distinctam. imperatores salutat et quae accipit verba pronuntiat, in vino praecipue lasciva. capiti eius duritia eadem quae rostro. hoc, cum loqui discit, ferreo verberatur radio; non sentit aliter ictus. cum devolat, rostro se excipit, illi innititur levioremque ita se pedum infirmitati facit.</td>
# <td class=val>quidem etiam sermocinantes</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/117" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/117</a></td>
# <td class=val>BIRD</td>
# <td class=val>avem</td>
# <td class=val>quidem etiam sermocinantes</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/120" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/120</a></td>
# <td class=val>starling</td>
# <td class=val>sturnum, item luscinias Graeco ac Latino sermone dociles, praeterea meditantes assidue et in diem nova loquentes, longiore etiam contextu. docentur secreto et ubi nulla alia vox misceatur, adsidente qui crebro dicat ea, quae condita velit, ac cibis blandiente</td>
# <td class=val>Graeco ac Latino sermone dociles, praeterea meditantes assidue et in diem nova loquentes, longiore etiam contextu</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/120" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/120</a></td>
# <td class=val>nightingale</td>
# <td class=val>sturnum, item luscinias Graeco ac Latino sermone dociles, praeterea meditantes assidue et in diem nova loquentes, longiore etiam contextu. docentur secreto et ubi nulla alia vox misceatur, adsidente qui crebro dicat ea, quae condita velit, ac cibis blandiente</td>
# <td class=val>Graeco ac Latino sermone dociles, praeterea meditantes assidue et in diem nova loquentes, longiore etiam contextu</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/124" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/124</a></td>
# <td class=val>WILD</td>
# <td class=val>feri</td>
# <td class=val>dein plura contexta verba exprimens et alia atque alia crebro addiscens</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/124" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/124</a></td>
# <td class=val>crow</td>
# <td class=val>nunc quoque erat in urbe Roma, haec prodente me, equitis Romani cornix e Baetica primum colore mira admodum nigro, dein plura contexta verba exprimens et alia atque alia crebro addiscens.</td>
# <td class=val>dein plura contexta verba exprimens et alia atque alia crebro addiscens</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/124" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/124</a></td>
# <td class=val>raven</td>
# <td class=val>Reddatur et corvis sua gratia, indignatione quoque populi Romani testata, non solum conscientia. Tiberio principe ex fetu supra Castorum aedem genito pullus in adpositam sutrinam devolavit, etiam religione commendatus officinae domino. is mature sermoni adsuefactus, omnibus matutinis evolans in rostra in forum versus, Tiberium, dein Germanicum et Drusum Caesares nominatim, mox transeuntem populum Romanum salutabat, postea ad tabernam remeans, plurium annorum adsiduo officio mirus.  [[122]] hunc sive aemulatione vicinitatis manceps proximae sutrinae sive iracundia subita, ut voluit videri, excrementis eius posita calceis macula, exanimavit, tanta plebei consternatione, ut primo pulsus ex ea regione, mox interemptus sit funusque aliti innumeris celebratum exequiis, constratum lectum super Aethiopum duorum umeros, praecedente tibicine et coronis omnium generum ad rogum usque, qui constructus dextra viae Appiae ad secundum lapidem in campo R&lt;e&gt;diculi appellato fuit.  [[123]] adeo satis iusta causa populo Romano visa est exequiarum ingenium avis aut supplicii de cive Romano in ea urbe, in qua multorum principum nemo deduxerat funus, Scipionis vero Aemiliani post Carthaginem Numantiamque deletas ab eo nemo vindicaverat mortem. [[124]] hoc gestum M. Servilio &lt;C&gt;. Cestio cos. a. d. V kal. Apriles.</td>
# <td class=val>dein plura contexta verba exprimens et alia atque alia crebro addiscens</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/137" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/137</a></td>
# <td class=val>ALES</td>
# <td class=val>alitum colloquia</td>
# <td class=val>alitum colloquia</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/137" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/137</a></td>
# <td class=val>ALES</td>
# <td class=val>alitum colloquia</td>
# <td class=val>avium sermonis</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/137" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/137</a></td>
# <td class=val>snake born from bird blood</td>
# <td class=val>aves quarum confuso sanguine serpens gignatur, quem quisquis ederit intellecturus sit alitum colloquia</td>
# <td class=val>alitum colloquia</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/137" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/137</a></td>
# <td class=val>snake born from bird blood</td>
# <td class=val>aves quarum confuso sanguine serpens gignatur, quem quisquis ederit intellecturus sit alitum colloquia</td>
# <td class=val>avium sermonis</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/137" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/137</a></td>
# <td class=val>BIRD</td>
# <td class=val>aves quarum confuso sanguine</td>
# <td class=val>avium sermonis</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/137" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/137</a></td>
# <td class=val>BIRD</td>
# <td class=val>avium sermonis</td>
# <td class=val>alitum colloquia</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/137" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/137</a></td>
# <td class=val>BIRD</td>
# <td class=val>ave</td>
# <td class=val>alitum colloquia</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/137" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/137</a></td>
# <td class=val>BIRD</td>
# <td class=val>aves quarum confuso sanguine</td>
# <td class=val>alitum colloquia</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/137" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/137</a></td>
# <td class=val>BIRD</td>
# <td class=val>ave</td>
# <td class=val>avium sermonis</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/137" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/137</a></td>
# <td class=val>BIRD</td>
# <td class=val>avium sermonis</td>
# <td class=val>avium sermonis</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/137" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/137</a></td>
# <td class=val>dragon1</td>
# <td class=val>Melampodi profecto aures lambendo dedisse intellectum avium sermonis dracones non abnuat</td>
# <td class=val>avium sermonis</td></tr><tr class=odd><td class=val><a href

# %% [markdown]
# # CQ 6

# %% [markdown]
# This query allows to identify the data provided about the gestation time of the animals

# %%
SELECT DISTINCT ?paragraph ?name_animal ?mention_animal ?mention_pregnancy WHERE {
?annotation1 a oa:Annotation;
              oa:hasBody ?animal;
              oa:hasTarget ?target1.
  ?target1 oa:hasSource ?paragraph;
     oa:hasSelector ?selector.
    
  ?selector oa:exact ?mention_animal.

  ?animal a skos:Concept;
       skos:prefLabel ?name_animal.
    
  ?animal_collection a skos:Collection;
       skos:prefLabel "Ancient class"@en;
       skos:member ?animal.

  ?annotation2 oa:hasBody ?pregnancy;
        oa:hasTarget ?target2.
  ?target2 oa:hasSource ?paragraph;
      oa:hasSelector ?selector2.
  ?selector2 oa:exact ?mention_pregnancy.

  ?pregnancy skos:prefLabel "length of pregnancy"@en.

  FILTER (lang(?name_animal) = "en").
}
ORDER BY ?paragraph
# Out:
# <div class="krn-spql"><table><tr class=hdr><th>paragraph</th>
# <th>name_animal</th>
# <th>mention_animal</th>
# <th>mention_pregnancy</th></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/147" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/147</a></td>
# <td class=val>swallow1</td>
# <td class=val>hirundines</td>
# <td class=val>a coitu X diebus ova maturescunt in utero, vexatis autem gallinae et columbae pinna evulsa aliave simili iniuria diutius</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/147" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/147</a></td>
# <td class=val>ringdove</td>
# <td class=val>palumbi</td>
# <td class=val>a coitu X diebus ova maturescunt in utero, vexatis autem gallinae et columbae pinna evulsa aliave simili iniuria diutius</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/147" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/147</a></td>
# <td class=val>blackbird</td>
# <td class=val>merulae</td>
# <td class=val>a coitu X diebus ova maturescunt in utero, vexatis autem gallinae et columbae pinna evulsa aliave simili iniuria diutius</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/147" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/147</a></td>
# <td class=val>turtledove</td>
# <td class=val>turtures</td>
# <td class=val>a coitu X diebus ova maturescunt in utero, vexatis autem gallinae et columbae pinna evulsa aliave simili iniuria diutius</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/147" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/147</a></td>
# <td class=val>thrush</td>
# <td class=val>turdi, in cacuminibus arborum luto nidificantes paene contextim, in secessu generant.</td>
# <td class=val>a coitu X diebus ova maturescunt in utero, vexatis autem gallinae et columbae pinna evulsa aliave simili iniuria diutius</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/147" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/147</a></td>
# <td class=val>hen</td>
# <td class=val>Quaedam omni tempore coeunt, ut gallinae, et pariunt, praeterquam duobus mensibus hiemis brumalibus. ex iis iuvencae plura quam veteres, sed minora, et in eodem fetu prima ac novissima. est autem tanta fecunditas, ut aliquae et sexagena pariant, aliquae cotidie, aliquae bis die, aliquae in tantum, ut effetae moriantur. Hadrianis laus maxima.</td>
# <td class=val>a coitu X diebus ova maturescunt in utero, vexatis autem gallinae et columbae pinna evulsa aliave simili iniuria diutius</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/147" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/147</a></td>
# <td class=val>hen</td>
# <td class=val>vexatis autem gallinae et columbae pinna evulsa aliave simili iniuria diutius</td>
# <td class=val>a coitu X diebus ova maturescunt in utero, vexatis autem gallinae et columbae pinna evulsa aliave simili iniuria diutius</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/161" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/161</a></td>
# <td class=val>hen</td>
# <td class=val>si gallinis subiciantur incubanda</td>
# <td class=val>partus excluditur diebus ter novenis aut tardius tricensimo</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/170" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/170</a></td>
# <td class=val>TERRESTRIAL</td>
# <td class=val>terrestrium</td>
# <td class=val>terti&lt;o&gt; die intra uterum catulos excludit</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/170" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/170</a></td>
# <td class=val>viper</td>
# <td class=val>viperae mas caput inserit in os, quod illa abrodit voluptatis dulcedine.  [[170]] terrestrium eadem sola intra se parit ova, unius coloris et mollia, ut pisces. terti&lt;o&gt; die intra uterum catulos excludit, dein singulis diebus singulos parit, XX fere numero. itaque ceteri tarditatis inpatientes perrumpunt latera occisa parente.</td>
# <td class=val>terti&lt;o&gt; die intra uterum catulos excludit</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/170" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/170</a></td>
# <td class=val>snake</td>
# <td class=val>Rursus in terrestribus ova pariunt serpentes, de quibus nondum dictum &lt;e&gt;st. coeunt conplexu, adeo circumvolutae sibi ipsae, ut una existimari biceps possit. viperae mas caput inserit in os, quod illa abrodit voluptatis dulcedine.  [[170]] terrestrium eadem sola intra se parit ova, unius coloris et mollia, ut pisces. terti&lt;o&gt; die intra uterum catulos excludit, dein singulis diebus singulos parit, XX fere numero. itaque ceteri tarditatis inpatientes perrumpunt latera occisa parente. ceterae serpentes contexta ova in terra incubant et fetum sequenti excludunt anno.</td>
# <td class=val>terti&lt;o&gt; die intra uterum catulos excludit</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/170" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/170</a></td>
# <td class=val>FISH</td>
# <td class=val>unius coloris et mollia, ut pisces</td>
# <td class=val>terti&lt;o&gt; die intra uterum catulos excludit</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/170" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/170</a></td>
# <td class=val>bat</td>
# <td class=val>Volucrum animal parit vespertilio tantum, cui et membranaceae pinnae uni. eadem sola volucrum lacte nutrit ubera admovens. parit geminos; volitat amplexa infantes secumque portat. eidem coxendi&lt;x&gt; una traditur e&lt;sse&gt;. in cibatu culices gratissimi.</td>
# <td class=val>terti&lt;o&gt; die intra uterum catulos excludit</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/175" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/175</a></td>
# <td class=val>goldfinch</td>
# <td class=val>acanthis duodenos, avis minima</td>
# <td class=val>ocissime pariunt quae plurimos gignunt.</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/175" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/175</a></td>
# <td class=val>goldfinch</td>
# <td class=val>acanthis duodenos, avis minima</td>
# <td class=val>quo maius est animal, tanto diutius formatur in utero. diutius gestantur quibus longiora sunt vitae spatia, neque crescentium tempestiva ad generandum aetas.</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/175" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/175</a></td>
# <td class=val>goldfinch</td>
# <td class=val>singulos gignunt elephanti, cameli, equi; acanthis duodenos</td>
# <td class=val>ocissime pariunt quae plurimos gignunt.</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/175" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/175</a></td>
# <td class=val>goldfinch</td>
# <td class=val>singulos gignunt elephanti, cameli, equi; acanthis duodenos</td>
# <td class=val>quo maius est animal, tanto diutius formatur in utero. diutius gestantur quibus longiora sunt vitae spatia, neque crescentium tempestiva ad generandum aetas.</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/175" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/175</a></td>
# <td class=val>BIRD</td>
# <td class=val>acanthis duodenos, avis minima</td>
# <td class=val>ocissime pariunt quae plurimos gignunt.</td></tr><tr class=odd><td class=val><a href="http://ww

# %% [markdown]
# # CQ7

# %% [markdown]
# This SPARQL query allows the scientist to target the animals capable of fasting and to understand their
# fasting and understand their diets

# %% [markdown]
# This query allows to

# %%
SELECT DISTINCT ?paragraph ?name_animal ?mention_animal ?mention_use WHERE {
?annotation1 a oa:Annotation;
              oa:hasBody ?animal;
              oa:hasTarget ?target1.
  ?target1 oa:hasSource ?paragraph;
     oa:hasSelector ?selector.
    
  ?selector oa:exact ?mention_animal.

  ?animal a skos:Concept;
       skos:prefLabel ?name_animal.
    
  ?animal_collection a skos:Collection;
       skos:prefLabel "Ancient class"@en;
       skos:member ?animal.

  ?annotation2 oa:hasBody ?use;
        oa:hasTarget ?target2.
  ?target2 oa:hasSource ?paragraph;
      oa:hasSelector ?selector2.
  ?selector2 oa:exact ?mention_use.

  ?use skos:prefLabel "technical use"@en.

  FILTER (lang(?name_animal) = "en").
}
ORDER BY ?paragraph
# Out:
# <div class="krn-spql"><table><tr class=hdr><th>paragraph</th>
# <th>name_animal</th>
# <th>mention_animal</th>
# <th>mention_use</th></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/2" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/2</a></td>
# <td class=val>BIRD</td>
# <td class=val>avium</td>
# <td class=val>praemia ex &lt;i&gt;is ova, propter amplitudinem pro quibusdam habita vasis</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-10-annoteIPL/10/2" target="_other">http://www.zoomathia.com/PLINE-10-annoteIPL/10/2</a></td>
# <td class=val>BIRD</td>
# <td class=val>avium</td>
# <td class=val>conosque bellicos et galeas adornantes pinnae</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-8-annoteIPL/8/124" target="_other">http://www.zoomathia.com/PLINE-8-annoteIPL/8/124</a></td>
# <td class=val>ass</td>
# <td class=val>villus magnitudine ursorum, sed, cum libuit sui coloris esse, asini similis</td>
# <td class=val>ut thoraces ex eo faciant</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-8-annoteIPL/8/124" target="_other">http://www.zoomathia.com/PLINE-8-annoteIPL/8/124</a></td>
# <td class=val>deer</td>
# <td class=val>caput maius cervino nec absimile</td>
# <td class=val>ut thoraces ex eo faciant</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-8-annoteIPL/8/124" target="_other">http://www.zoomathia.com/PLINE-8-annoteIPL/8/124</a></td>
# <td class=val>bear</td>
# <td class=val>villus magnitudine ursorum, sed, cum libuit sui coloris esse, asini similis</td>
# <td class=val>ut thoraces ex eo faciant</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-8-annoteIPL/8/226" target="_other">http://www.zoomathia.com/PLINE-8-annoteIPL/8/226</a></td>
# <td class=val>weasel</td>
# <td class=val>In Poroselene insula viam mustelae non transeunt.</td>
# <td class=val>Quarum e pellibus cubicularia vidimus stragula</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-8-annoteIPL/8/226" target="_other">http://www.zoomathia.com/PLINE-8-annoteIPL/8/226</a></td>
# <td class=val>mole</td>
# <td class=val>Item Boeotiae Lebadeae inlatae solum ipsum fugiunt, quae iuxta in Orchomeno tota arva subruunt, talpae. Quarum e pellibus cubicularia vidimus stragula: adeo ne religio quidem a portentis submovet delicias.</td>
# <td class=val>Quarum e pellibus cubicularia vidimus stragula</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-8-annoteIPL/8/226" target="_other">http://www.zoomathia.com/PLINE-8-annoteIPL/8/226</a></td>
# <td class=val>hare</td>
# <td class=val>In Ithaca lepores inlati moriuntur extremis quidem in litoribus</td>
# <td class=val>Quarum e pellibus cubicularia vidimus stragula</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-9-annoteIPL/9/148" target="_other">http://www.zoomathia.com/PLINE-9-annoteIPL/9/148</a></td>
# <td class=val>FISH</td>
# <td class=val>pisces</td>
# <td class=val>ex quo penicilli</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-9-annoteIPL/9/148" target="_other">http://www.zoomathia.com/PLINE-9-annoteIPL/9/148</a></td>
# <td class=val>tragos</td>
# <td class=val>spissum ac praedurum et asperum tragos [id] vocatur</td>
# <td class=val>ex quo penicilli</td></tr><tr class=odd><td class=val><a href="http://www.zoomathia.com/PLINE-9-annoteIPL/9/148" target="_other">http://www.zoomathia.com/PLINE-9-annoteIPL/9/148</a></td>
# <td class=val>manos</td>
# <td class=val>spissum et mollius manos</td>
# <td class=val>ex quo penicilli</td></tr><tr class=even><td class=val><a href="http://www.zoomathia.com/PLINE-9-annoteIPL/9/148" target="_other">http://www.zoomathia.com/PLINE-9-annoteIPL/9/148</a></td>
# <td class=val>achillium</td>
# <td class=val>tenue densumque, ex quo penicilli, Achillium</td>
# <td class=val>ex quo penicilli</td></tr></table><div class="tinfo">Total: 12, Shown: 12</div></div>
